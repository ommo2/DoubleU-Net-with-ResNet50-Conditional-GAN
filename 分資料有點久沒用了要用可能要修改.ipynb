# %%
from shutil import copyfile
import os
import random
def split_data(path,des_path,train_percent=8,validation_percent=1,test_percent=1):
    #防呆
    if train_percent+validation_percent+test_percent!=10:
        print("train_percent+validation_percent+test_percent要等於10")
        return False
    #建立所需資料夾
    os.mkdir(des_path)
    os.mkdir(os.path.join(des_path,"train"))
    os.mkdir(os.path.join(des_path,"validation"))
    os.mkdir(os.path.join(des_path,"test"))
    os.mkdir(os.path.join(des_path,"left"))
    for i in os.listdir(path):
        os.mkdir(os.path.join(des_path,"train",i))
        os.mkdir(os.path.join(des_path,"validation",i))
        os.mkdir(os.path.join(des_path,"test",i))
        os.mkdir(os.path.join(des_path,"left",i))

        #每個圖片的檔名list(不包含路徑)
        pic_path=os.listdir(os.path.join(path,i)) 

        for k in pic_path:
            if ".jpg" not in k:
                pic_path.remove(k)
        
        #洗牌
        random.shuffle(pic_path)
        #算比例
        train_num=len(pic_path)//10*train_percent
        validation_num=len(pic_path)//10*validation_percent
        test_num=len(pic_path)//10*test_percent

        
        for j in pic_path[:400]:
            copyfile(os.path.join(path,i,j),os.path.join(des_path,"train",i,j))
            copyfile(os.path.join(path,i,j.replace(".jpg",".xml")),os.path.join(des_path,"train",i,j.replace(".jpg",".xml")))
        for j in pic_path[400:550]:
            copyfile(os.path.join(path,i,j),os.path.join(des_path,"validation",i,j))
            copyfile(os.path.join(path,i,j.replace(".jpg",".xml")),os.path.join(des_path,"validation",i,j.replace(".jpg",".xml")))
        for j in pic_path[550:700]:
            copyfile(os.path.join(path,i,j),os.path.join(des_path,"test",i,j))
            copyfile(os.path.join(path,i,j.replace(".jpg",".xml")),os.path.join(des_path,"test",i,j.replace(".jpg",".xml")))
        
        for j in pic_path[700:]:
            copyfile(os.path.join(path,i,j),os.path.join(des_path,"left",i,j))
            copyfile(os.path.join(path,i,j.replace(".jpg",".xml")),os.path.join(des_path,"left",i,j.replace(".jpg",".xml")))

# %%
IMAGE_GEN_DIR="data_all_高清"
DEST_PATH="data_split_高清"
split_data(IMAGE_GEN_DIR,DEST_PATH,8,1,1)

# %%
from shutil import copyfile
import os
import random
def split_data(path,des_path,train_percent=8,validation_percent=1,test_percent=1):
    #防呆
    if train_percent+validation_percent+test_percent!=10:
        print("train_percent+validation_percent+test_percent要等於10")
        return False
    #建立所需資料夾
    os.mkdir(des_path)
    os.mkdir(os.path.join(des_path,"train"))
    os.mkdir(os.path.join(des_path,"validation"))
    os.mkdir(os.path.join(des_path,"test"))
    os.mkdir(os.path.join(des_path,"left"))
    for i in os.listdir(path):
        os.mkdir(os.path.join(des_path,"train",i))
        os.mkdir(os.path.join(des_path,"validation",i))
        os.mkdir(os.path.join(des_path,"test",i))
        os.mkdir(os.path.join(des_path,"left",i))

        #每個圖片的檔名list(不包含路徑)
        pic_path=os.listdir(os.path.join(path,i)) 

        for k in pic_path:
            if ".jpg" not in k:
                pic_path.remove(k)
        
        #洗牌
        random.shuffle(pic_path)
        #算比例
        train_num=len(pic_path)//10*train_percent
        validation_num=len(pic_path)//10*validation_percent
        test_num=len(pic_path)//10*test_percent

        
        for j in pic_path[:612]:
            copyfile(os.path.join(path,i,j),os.path.join(des_path,"train",i,j))
            copyfile(os.path.join(path,i,j.replace(".jpg",".xml")),os.path.join(des_path,"train",i,j.replace(".jpg",".xml")))
    #    for j in pic_path[492:552]:
    #        copyfile(os.path.join(path,i,j),os.path.join(des_path,"validation",i,j))
    #        copyfile(os.path.join(path,i,j.replace(".jpg",".xml")),os.path.join(des_path,"validation",i,j.replace(".jpg",".xml")))
    #    for j in pic_path[552:612]:
    #        copyfile(os.path.join(path,i,j),os.path.join(des_path,"test",i,j))
    #        copyfile(os.path.join(path,i,j.replace(".jpg",".xml")),os.path.join(des_path,"test",i,j.replace(".jpg",".xml")))
        
        for j in pic_path[612:]:
            copyfile(os.path.join(path,i,j),os.path.join(des_path,"left",i,j))
            copyfile(os.path.join(path,i,j.replace(".jpg",".xml")),os.path.join(des_path,"left",i,j.replace(".jpg",".xml")))
